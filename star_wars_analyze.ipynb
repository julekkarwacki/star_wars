# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('StarWars.csv', encoding='latin1')

# %%
data
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# ...            ...
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                 No
# 1185                                                Yes
# 1186                                                Yes
#
# ...

# %%
data.drop(columns='RespondentID', inplace=True)

# %%
data.head()
# Out:
#   Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
data['Location (Census Region)'].value_counts()
# Out:
# East North Central    181
# Pacific               175
# South Atlantic        170
# Middle Atlantic       122
# West South Central    110
# West North Central     93
# Mountain               79
# New England            75
# East South Central     38
# Response                1
# Name: Location (Census Region), dtype: int64

# %%
data['Unnamed: 8']
# Out:
# 0       Star Wars: Episode VI Return of the Jedi
# 1       Star Wars: Episode VI Return of the Jedi
# 2                                            NaN
# 3                                            NaN
# 4       Star Wars: Episode VI Return of the Jedi
#                           ...
# 1182    Star Wars: Episode VI Return of the Jedi
# 1183    Star Wars: Episode VI Return of the Jedi
# 1184                                         NaN
# 1185    Star Wars: Episode VI Return of the Jedi
# 1186    Star Wars: Episode VI Return of the Jedi
# Name: Unnamed: 8, Length: 1187, dtype: object

# %%
data.dropna()
# Out:
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                              Response
# 5                                                   Yes
# 6                                                   Yes
# 16                                                  Yes
# 23                                                  Yes
# ...                                                 ...
# 1128                                                Yes
# 1129                                                Yes
# 1153                                                Yes
# 1172                                                Yes
# 1176                                                Yes
#
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 5                                                   Yes
# 6                                                   Yes
# ...

# %%
grupowanie = data.groupby(['Gender', 'Age'])['Have you seen any of the 6 films in the Star Wars franchise?']

# %%
grupowanie.count()
# Out:
# Gender    Age
# Female    18-29       114
#           30-44       136
#           45-60       151
#           > 60        148
# Male      18-29       104
#           30-44       132
#           45-60       140
#           > 60        121
# Response  Response      1
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
data.rename(columns={'Czy widziałeś kiedykolwiek ten film': 'Have you seen any of the 6 films in the Star Wars franchise?'}, inplace=True)

# %%
data['Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.']
# Out:
# 0       Star Wars: Episode I  The Phantom Menace
# 1                                              3
# 2                                            NaN
# 3                                              1
# 4                                              5
#                           ...
# 1182                                           5
# 1183                                           4
# 1184                                         NaN
# 1185                                           4
# 1186                                           6
# Name: Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film., Length: 1187, dtype: object

# %%
frame = data['Have you seen any of the 6 films in the Star Wars franchise?'].fillna('Brak danych')

# %%
frame[frame == 'Response'] = 'Nieznana'

# %%
counts = frame.value_counts()
counts
# Out:
# Yes         936
# No          250
# Nieznana      1
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
sns.barplot(y=counts.index, x=counts.values)
# Out:
# <AxesSubplot:>

# %%
grupowanie.count()
# Out:
# Gender    Age
# Female    18-29       114
#           30-44       136
#           45-60       151
#           > 60        148
# Male      18-29       104
#           30-44       132
#           45-60       140
#           > 60        121
# Response  Response      1
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
grupowanie.name = 'total'

# %%
wynik = grupowanie.count().fillna(0)
wynik
# Out:
# Gender    Age
# Female    18-29       114
#           30-44       136
#           45-60       151
#           > 60        148
# Male      18-29       104
#           30-44       132
#           45-60       140
#           > 60        121
# Response  Response      1
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
wynik = wynik.drop(index='Response', columns='Response')

# %%
wynik = wynik.reset_index()

# %%
wynik.name = 'liczba osób'
wynik
# Out:
#    Gender    Age  liczba osób
# 0  Female  18-29          114
# 1  Female  30-44          136
# 2  Female  45-60          151
# 3  Female   > 60          148
# 4    Male  18-29          104
# 5    Male  30-44          132
# 6    Male  45-60          140
# 7    Male   > 60          121

# %%
sns.barplot(y='liczba osób', x='Gender', hue='Age', data=wynik).set(title='Kto widział Star Warsy z podziałem na płeć i wiek')
# Out:
# [Text(0.5, 1.0, 'Kto widział Star Warsy z podziałem na płeć i wiek')]

# %%
kobiety_czy_mężczyźni = wynik.groupby('Gender')['liczba osób'].sum()

# %%
kobiety_czy_mężczyźni
# Out:
# Gender
# Female    549
# Male      497
# Name: liczba osób, dtype: int64

# %%
kobiety_czy_mężczyźni.plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
wyksztalcenie = data.groupby(['Household Income', 'Education'])

# %%
df = data['Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.'].fillna('Brak danych')

# %%
df
# Out:
# 0       Star Wars: Episode I  The Phantom Menace
# 1                                              3
# 2                                    Brak danych
# 3                                              1
# 4                                              5
#                           ...
# 1182                                           5
# 1183                                           4
# 1184                                 Brak danych
# 1185                                           4
# 1186                                           6
# Name: Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film., Length: 1187, dtype: object

# %%
data.rename(columns={'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.': 'Star Wars I'}, inplace=True)

# %%
data.rename(columns={'Unnamed: 10': 'Star Wars II', 'Unnamed: 11': 'Star Wars III', 'Unnamed: 12': 'Star Wars IV',
                     'Unnamed: 13': 'Star Wars V', 'Unnamed: 14': 'Star Wars VI'}, inplace=True)

# %%
star_4 = data['Star Wars IV'].dropna().value_counts()

# %%
star_1 = data['Star Wars I'].dropna().value_counts()

# %%
star_3 = data['Star Wars III'].dropna().value_counts()

# %%
star_6 = data['Star Wars VI'].dropna().value_counts()

# %%
star_5 = data['Star Wars V'].dropna().value_counts()

# %%
star_2 = data['Star Wars II'].dropna().value_counts()

# %%
star_1 = star_1[3]
star_2 = star_2[5]
star_3 = star_3[5]
star_4 = star_4[0]
star_5 = star_5[0]
star_6 = star_6[2]

# %%
analiza = pd.DataFrame([star_1, star_2, star_3, star_4, star_5, star_6], index=['Star Wars 1', 'Star Wars 2', 'Star Wars 3', 'Star Wars 4', 'Star Wars 5', 'Star Wars 6'])

# %%
analiza = analiza.rename(columns={0: 'Liczba głosów'})

# %%
analiza
# Out:
#              Liczba głosów
# Star Wars 1            129
# Star Wars 2             32
# Star Wars 3             36
# Star Wars 4            204
# Star Wars 5            289
# Star Wars 6            146

# %%
analiza.plot(kind='bar', rot=45, title='Która część jest najlepsza?')
# Out:
# <AxesSubplot:title={'center':'Która część jest najlepsza?'}>

# %%
analiza.index
# Out:
# Index(['Star Wars 1', 'Star Wars 2', 'Star Wars 3', 'Star Wars 4',
#        'Star Wars 5', 'Star Wars 6'],
#       dtype='object')

# %%
analiza.plot(kind='bar', title='Która część jest najlepsza', rot=30, figsize=(9, 5))
# Out:
# <AxesSubplot:title={'center':'Która część jest najlepsza'}>

# %%
data.head()
# Out:
#   Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
data['Location (Census Region)'].value_counts() #skąd najwięcej przyslanych ankiet
# Out:
# East North Central    181
# Pacific               175
# South Atlantic        170
# Middle Atlantic       122
# West South Central    110
# West North Central     93
# Mountain               79
# New England            75
# East South Central     38
# Response                1
# Name: Location (Census Region), dtype: int64
